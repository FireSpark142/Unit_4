# %%
"""
Your task in this exercise has two steps:

- audit the OSMFILE and change the variable 'mapping' to reflect the changes needed to fix 
    the unexpected street types to the appropriate ones in the expected list.
    You have to add mappings only for the actual problems you find in this OSMFILE,
    not a generalized solution, since that may and will depend on the particular area you are auditing.
- write the update_name function, to actually fix the street name.
    The function takes a string with street name as an argument and should return the fixed name
    We have provided a simple test so that you see what exactly is expected
"""
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE = "C:\Users\Marcus\Downloads\stchas.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

mapping = { "St": "Street",
            "Rd.": "Road",
            "Rd": "Road",
            "N.": "North",
            "S.": "South",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
            "Expy": "Expressway",
            "Ln": "Lane",
            "Ctr": "Center",
            "Ctr.": "Center",
            #There was a street named just dade...that's it..so I went on google to find the real address, so this corrects that occurance.
            "Dade": "South Dade Avenue",
          }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types



def update_name(name, mapping):
    nameParts= []
    name = name.split()
    for index, part in enumerate(name):
        if part in mapping.keys():
            nameParts.append(mapping[part])
        else:
            nameParts.append(part)
       
    better_name = ' '.join(nameParts)
    return better_name

def test():
    st_types = audit(OSMFILE)
    len(st_types)
    pprint.pprint(dict(st_types))

    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name
            if name == "N. Main Ctr.":
                assert better_name == "North Main Center"
            if name == "Zumbehl Rd":
               assert better_name == "Zumbehl Road"


if __name__ == '__main__':
    test()
# Out:
# {'364': set(['South Outer 364']),
#  '40-61': set(['Highway 40-61']),
#  '67': set(['N Highway 67', 'North Highway 67']),
#  '79': set(['Highway 79', 'Old Highway 79']),
#  '94': set(['Highway 94',
#             'Plaza 94',
#             'S. Hwy  94',
#             'South Highway 94',
#             'South Old Highway 94']),
#  'Acres': set(['Woodcliff Acres']),
#  'B': set(['Highway B']),
#  'Blvd': set(['N Lindbergh Blvd', 'St Louis Mills Blvd']),
#  'Blvd.': set(['Lambert International Blvd.']),
#  'C': set(['Highway C']),
#  'Caballo': set(['El Caballo']),
#  'Center': set(['Florissant Oaks Shopping Center',
#                 'Mid Rivers Center',
#                 'Mullanphy Gardens Shopping Center',
#                 'Paddock Hills Shopping Center']),
#  'Circle': set(['Addyston Circle',
#                 'Angle Gate Circle',
#                 'Asher Circle',
#                 'Aspencade Circle',
#                 'Auburn Circle',
#                 'Avocado Tree Circle',
#                 'Bardic Circle',
#                 'Belcourt Circle',
#                 'Bentley Park Circle',
#                 'Bernie Circle',
#                 'Berry Manor Circle',
#                 'Blouff Manor Circle',
#                 'Bobbinray Circle',
#                 'Breckenridge Circle',
#                 'Bridgeton Valley Circle',
#                 'Brierhall Circle',
#                 'Brittany Circle',
#                 'Claycrest Circle',
#                 'Commons Circle',
#                 'Concord View Circle',
#                 'Country Park Circle',
#                 'Country Squire Circle',
#                 'Delegate Circle',
#                 'Democracy Circle',
#                 'Douglas Fir Circle',
#                 'Du Pre Circle',
#                 'Dunmore Circle',
#                 'England Circle',
#                 'Fawn Valley Circle',
#                 'Georgetown Circle',
#                 'Gillette Circle',
#                 'Gingerwood Circle',
#                 'Grand Slam Circle',
#                 'Green Pines Circle',
#                 'Harvest Home Circle',
#                 'Haven View Circle',
#                 'Hawthorne Circle',
#                 'Heather Valley Circle',
#                 'Hennsley Circle',
#                 'Heritage Manor Circle',
#                 'Imperial Circle',
#                 'Ingalls Circle',
#                 'Jacobs Circle',
#                 'Jacobs Creek Circle',
#                 'Jaqueline Circle',
#                 'Jungermann Circle',
#                 'La Havre Circle',
#                 'Landing Circle',
#                 'Lands End Circle',
#                 'Laurel Village Circle',
#                 'Logan Crossing Circle',
#                 'Lori Circle',
#                 'Magnolia Manor Circle',
#                 'Maryland Circle',
#                 'McGregor Circle',
#                 'Merryfield Circle',
#                 'Mid Rivers Mall Circle',
#                 'Mill Pond Circle',
#                 'Montague Circle',
#                 'NcCkay Village Circle',
#                 'Newkirk Circle',
#                 'Northwest Industrial Circle',
#                 'Olvera Circle',
#                 'Park Ashwood Circle',
#                 'Pauley Circle',
#                 'Pegasus Circle',
#                 'Pendleton Circle',
#                 'Piedmont Circle',
#                 'Plantation Manor Circle',
#                 'Plum Leaf Circle',
#                 'Reddington Timbers Circle',
#                 'Research Park Circle',
#                 'Ridgeland Circle',
#                 'Ridgetop Circle',
#                 'Roselake Circle',
#                 'Savannah Circle',
#                 'Settlers Circle',
#                 'Shepherds Hill Circle',
#                 'Show Boat Circle',
#                 'Soenker Circle',
#                 'Summergate Circle',
#                 'Sunset Villa Circle',
#                 'Tisbury Circle',
#                 'Treebeard Circle',
#                 'Tri Sports Circle',
#                 'Trinity Circle',
#                 'Tuckahoe Circle',
#                 'Twinleaf Circle',
#                 'Venice Circle',
#                 'Waterford Crystal Circle',
#                 'Wavecrest Circle',
#                 'West Park Circle',
#                 'Westhampton Place Circle',
#                 'Winding Trails Circle',
#                 'Woodbury Place Circle',
#                 'Woodmere Circle']),
#  'Close': set(['Clonmel Close', 'Gillette Field Close', 'Kylemore Close']),
#  'Club': set(['Elmer Dwyer Club', 'Hodges Club']),
#  'Common': set(['Bourbeuse Common']),
#  'Condotti': set(['Via Condotti']),
#  'Corner': set(['Brimstone Corner']),
#  'Cove': set(['Brittany Cove', 'Cades Cove', 'Mystic Cove']),
#  'Creek': set(['Spring Mill Creek']),
#  'Cross': set(['Little Gore Cross']),
#  'Crossing': set(['Bramblett Crossing',
#                   'Chad Crossing',
#                   'Chapel Hill Crossing',
#                   'Cottage Crossing',
#                   'Hampton Crossing',
#                   'Heritage Crossing',
#                   'Keighly Crossing',
#                   'Kings Crossing',
#                   'Kingston Crossing',
#                   'Klondike Crossing',
#                   'Millers Crossing',
#                   'Newbury Crossing',
#                   'Raintree Crossing',
#                   'Rascal Crossing',
#                   'Rivercity Crossing',
#                   'Spencers Crossing',
#                   'Westfield Crossing',
#                   'Woodmere Crossing',
#                   'Zumwalt Crossing']),
#  'Ctr': set(['North Main Ctr']),
#  'Ctr.': set(['N. Main Ctr.']),
#  'D': set(['MO D']),
#  'Dade': set(['Dade']),
#  'Down': set(['Killary Down']),
#  'Downs': set(['Braxton Downs', 'Merrimac Downs', 'Preston Downs']),
#  'East': set(['Carriage Way East',
#               'Graybridge East',
#               'Jacobs Court East',
#               'Mexico Loop Road East',
#               'Round Tower Drive East',
#               'Saddlehorn Court East']),
#  'Expressway': set(['Earth City Expressway', 'Maryland Heights Expressway']),
#  'Expy': set(['Maryland Heights Expy']),
#  'Forge': set(['Valley Forge']),
#  'Francois': set(['Rue Saint Francois']),
#  'Grove': set(['Carters Grove']),
#  'H': set(['Highway H']),
#  'Harbor': set(['Holiday Harbor', 'Weule Boat Harbor']),
#  'Heights': set(['Saratoga Heights']),
#  'Hill': set(['Bunker Hill', 'Constellation Hill']),
#  'Hills': set(['Bramblett Hills']),
#  'Hollow': set(['Bramblett Hollow', 'Musket Hollow']),
#  'Junction': set(['Cactus Junction']),
#  'K': set(['Highway K']),
#  'Kingshighway': set(['Kingshighway']),
#  'Ladder': set(['Jacobs Ladder']),
#  'Landing': set(['Cumberland Landing',
#                  'Gettysburg Landing',
#                  'Hampton Landing',
#                  'Heritage Landing',
#                  'Hudson Landing',
#                  'Jacobs Landing',
#                  'Lexington Landing',
#                  'Teal Landing']),
#  'Ln': set(['Eagle Crest Ln', 'W Saint Anthony Ln']),
#  'Loop': set(['Home Villa Loop']),
#  'MO-94': set(['MO-94']),
#  'Mall': set(['Mid Rivers Mall']),
#  'Manor': set(['Hansen Manor', 'Wabash Manor']),
#  'Mill': set(['Hobbs Mill']),
#  'N': set(['Route N']),
#  'North': set(['Barley Ridge Court North',
#                'Biddeford Court North',
#                'Briar Valley Court North',
#                'Bristlecone Court North',
#                'Ciera Ridge Court North',
#                'Executive Centre Parkway Loop North',
#                'Grasslands Court North',
#                'Harris Drive North',
#                'Highway 94 North',
#                'Hutchings Farm Boulevard North',
#                'Hutchings Farm Drive North',
#                'Muirfield Court North',
#                'Muirfield Hill Court North',
#                'Park Charles Boulevard North',
#                'Rider Trail North',
#                'Saddlebrook Court North',
#                'Upper Muirfield Court North',
#                'Valley Vista Drive North',
#                'Westerfield Drive North']),
#  'P': set(['Highway P']),
#  'Park': set(['Lexington Park',
#               'Missoula Park',
#               'Palladio Park',
#               'Piedmont Park']),
#  'Pass': set(['Chickasaw Pass',
#               'Claremoor Pass',
#               'Donner Pass',
#               'Fallon Pass',
#               'Hughes Pass',
#               'Laws Pass',
#               'Lexington Pass',
#               'Loughmor Pass',
#               'Loveland Pass',
#               'Newgrange Pass',
#               'Radford Pass',
#               'Raintree Pass',
#               'Renaud Pass',
#               'Rivercity Pass',
#               'Vantage Pass',
#               'Zumwalt Pass']),
#  'Path': set(['Arabian Path',
#               'Garden Path',
#               'Katiebriar Path',
#               'Palomino Path']),
#  'Plaza': set(['5th Plaza',
#                'American Eagle Plaza',
#                'Crossroads Plaza',
#                'Earth City Plaza',
#                'Magellan Plaza',
#                "O'Fallon Plaza",
#                'Patterson Plaza',
#                'Runny Meade Plaza']),
#  'Point': set(['Pioneer Point', 'Plantation Point', 'Prairie Point']),
#  'Pointe': set(['Auburn Trace Pointe']),
#  'RD': set(['CHURCH RD']),
#  'Ranch': set(['Clydesdale Ranch']),
#  'Rd': set(['Dorsett Rd',
#             'Graham Rd',
#             'Howdershell Rd',
#             'Independence Rd',
#             'Missouri Bottom Rd',
#             "O'Fallon Rd",
#             'Zumbehl Rd']),
#  'Ride': set(['Reveres Ride']),
#  'Ridge': set(['Celestial Ridge',
#                'Copper Ridge',
#                'Eagles Hill Ridge',
#                'Horseshoe Ridge',
#                'Millers Ridge',
#                'Silver Ridge']),
#  'Ring': set(['West Meath Ring']),
#  'Row': set(['Alexandria Row']),
#  'Run': set(['Caribou Run',
#              'Deer Run',
#              'Elk Run',
#              'Everwood Run',
#              'Grey Fox Run',
#              'Kesslers Run',
#              'Timber Run',
#              'Wallowa Run',
#              'Wild Fox Run']),
#  'Saratoga': set(['Fort Saratoga']),
#  'South': set(['Barley Ridge Court South',
#                'Briar Valley Court South',
#                'Bristlecone Court South',
#                'Ciera Ridge Court South',
#                'Hutchings Farm Boulevard South',
#                'Hutchings Farm Drive South',
#                'Muirfield Court South',
#                'Muirfield Hill Court South',
#                'Park Charles Boulevard South',
#                'Rider Trail South',
#                'Saddlebrook Court South',
#                'Upper Muirfield Court South',
#                'Valley Vista Drive South',
#                'Westerfield Drive South']),
#  'St': set(['N 3rd St', 'N 4th St', 'Randolph St', 'West Randolph St']),
#  'Station': set(['Coachlight Station',
#                  'Comstock Station',
#                  'Greystone Station',
#                  'Heritage Station',
#                  'Jungs Station',
#                  'Stonewall Station',
#                  'Summit Station',
#                  'Trenton Station',
#                  'Vicksburg Station']),
#  'Summit': set(['Glen Summit']),
#  'Terrace': set(['Knoll Terrace', 'Lennox Terrace', 'Montecito Terrace']),
#  'Trace': set(['Comanche Trace', 'Mohawk Trace', 'Sioux Trace']),
#  'Trails': set(['Morgan Trails']),
#  'Valley': set(['Bramblett Valley']),
#  'Village': set(['Dorsett Village', 'Woodgate Village']),
#  'Way': set(['Annapolis Way',
#              'Arapahoe Way',
#              'Athena Way',
#              'Aventura Way',
#              'Barvarian Way',
#              'Biltmore Way',
#              'Bordeaux Way',
#              'Braddock Way',
#              'Britain Way',
#              'Brooklands Way',
#              'Candice Way',
#              'Capri Way',
#              'Chippewa Way',
#              'Circle Way',
#              'Club Way',
#              'Coachman Way',
#              'Confederate Way',
#              'Congress Way',
#              'Costco Way',
#              'Dixie Way',
#              'Dresden Way',
#              'Enterprise Way',
#              'Entrance Way',
#              'Fair Vue Way',
#              'Floral Way',
#              'Fort Sumter Way',
#              'Gene Way',
#              'Hargrove Way',
#              'Harmony Villa Way',
#              'Hesters Way',
#              'Hilltop Way',
#              'Holman Way',
#              'Jacobs Way',
#              'Justin Way',
#              'Kindred Way',
#              'Kipling Way',
#              'Lamplighter Way',
#              'Mallards Way',
#              'Marbury Way',
#              'Maryells Way',
#              'McCauley Way',
#              'Meramec Way',
#              'Miralago Way',
#              'Molina Way',
#              'Monitor Way',
#              'New Freedom Way',
#              'North Biltmore Way',
#              'North Joyce Ellen Way',
#              'Olympic Way',
#              'Orion Way',
#              'Osage Way',
#              'Ozark Way',
#              'Pleasant Vue Way',
#              'Prairie Sky Way',
#              'Rams Way',
#              'Rebels Way',
#              'Redemption Way',
#              'Robert Johns Way',
#              'Rosebud Way',
#              'Royallvalley Way',
#              'Royallview Way',
#              'Royalvalley Way',
#              'Rush Creek Way',
#              'San Marco Way',
#              'Saw Mill Way',
#              'Sorano Way',
#              'South Biltmore Way',
#              'South Joyce Ellen Way',
#              'Southern Mill Way',
#              'Stansbury Way',
#              'Staunton Way',
#              'Suns Up Way',
#              'Tennessee Walker Way',
#              'Toscana Way',
#              'Trappers Way',
#              'Travelers Way',
#              'Union Way',
#              'Ventures Way',
#              'Wabash Woods Way',
#              'Willow Way',
#              'Winchester Way',
#              'Wistar Way',
#              'Wisteria Way',
#              'Wolfrum Way',
#              'Wood Manor Way',
#              'World Wide Way']),
#  'West': set(['Biddeford Court West',
#               'Carriage Way West',
#               'Douglas Drive West',
#               'Industrial Park Place West',
#               'Jacobs Court West',
#               'Mexico Loop Road West',
#               'Round Tower Drive West',
#               'Saddlehorn Court West']),
#  'Woods': set(['Spring Mill Woods'])}
# Celestial Ridge => Celestial Ridge
# Silver Ridge => Silver Ridge
# Copper Ridge => Copper Ridge
# Millers Ridge => Millers Ridge
# Eagles Hill Ridge => Eagles Hill Ridge
# Horseshoe Ridge => Horseshoe Ridge
# El Caballo => El Caballo
# Auburn Trace Pointe => Auburn Trace Pointe
# Little Gore Cross => Little Gore Cross
# Eagle Crest Ln => Eagle Crest Lane
# W Saint Anthony Ln => W Saint Anthony Lane
# Piedmont Park => Piedmont Park
# Lexington Park => Lexington Park
# Palladio Park => Palladio Park
# Missoula Park => Missoula Park
# Highway B => Highway B
# Maryland Heights Expy => Maryland Heights Expressway
# Woodcliff Acres => Woodcliff Acres
# O'Fallon Rd => O'Fallon Road
# Graham Rd => Graham Road
# Missouri Bottom Rd => Missouri Bottom Road
# Zumbehl Rd => Zumbehl Road
# Dorsett Rd => Dorsett Road
# Independence Rd => Independence Road
# Howdershell Rd => Howdershell Road
# Trenton Station => Trenton Station
# Vicksburg Station => Vicksburg Station
# Comstock Station => Comstock Station
# Jungs Station => Jungs Station
# Stonewall Station => Stonewall Station
# Heritage Station => Heritage Station
# Coachlight Station => Coachlight Station
# Greystone Station => Greystone Station
# Summit Station => Summit Station
# Constellation Hill => Constellation Hill
# Bunker Hill => Bunker Hill
# Rosebud Way => Rosebud Way
# Tennessee Walker Way => Tennessee Walker Way
# Marbury Way => Marbury Way
# Braddock Way => Braddock Way
# New Freedom Way => New Freedom Way
# Travelers Way => Travelers Way
# Willow Way => Willow Way
# Maryells Way => Maryells Way
# Biltmore Way => Biltmore Way
# Rebels Way => Rebels Way
# Club Way => Club Way
# Wisteria Way => Wisteria Way
# Molina Way => Molina Way
# South Joyce Ellen Way => South Joyce Ellen Way
# Toscana Way => Toscana Way
# Hesters Way => Hesters Way
# Hargrove Way => Hargrove Way
# Britain Way => Britain Way
# McCauley Way => McCauley Way
# Lamplighter Way => Lamplighter Way
# Enterprise Way => Enterprise Way
# Annapolis Way => Annapolis Way
# Rush Creek Way => Rush Creek Way
# Barvarian Way => Barvarian Way
# Olympic Way => Olympic Way
# Rams Way => Rams Way
# Entrance Way => Entrance Way
# Capri Way => Capri Way
# Sorano Way => Sorano Way
# Meramec Way => Meramec Way
# Osage Way => Osage Way
# Saw Mill Way => Saw Mill Way
# Royallvalley Way => Royallvalley Way
# Union Way => Union Way
# Candice Way => Candice Way
# Floral Way => Floral Way
# Confederate Way => Confederate Way
# Coachman Way => Coachman Way
# Staunton Way => Staunton Way
# Redemption Way => Redemption Way
# Congress Way => Congress Way
# Suns Up Way => Suns Up Way
# Ozark Way => Ozark Way
# Fair Vue Way => Fair Vue Way
# Royallview Way => Royallview Way
# Brooklands Way => Brooklands Way
# Harmony Villa Way => Harmony Villa Way
# Ventures Way => Ventures Way
# Chippewa Way => Chippewa Way
# Dixie Way => Dixie Way
# North Joyce Ellen Way => North Joyce Ellen Way
# World Wide Way => World Wide Way
# Southern Mill Way => Southern Mill Way
# Bordeaux Way => Bordeaux Way
# Gene Way => Gene Way
# Circle Way => Circle Way
# San Marco Way => San Marco Way
# Robert Johns Way => Robert Johns Way
# Wood Manor Way => Wood Manor Way
# Mallards Way => Mallards Way
# Royalvalley Way => Royalvalley Way
# Wabash Woods Way => Wabash Woods Way
# Arapahoe Way => Arapahoe Way
# Monitor Way => Monitor Way
# Miralago Way => Miralago Way
# Wolfrum Way => Wolfrum Way
# Hilltop Way => Hilltop Way
# Costco Way => Costco Way
# Aventura Way => Aventura Way
# Holman Way => Holman Way
# Prairie Sky Way => Prairie Sky Way
# Kindred Way => Kindred Way
# Kipling Way => Kipling Way
# Orion Way => Orion Way
# Pleasant Vue Way => Pleasant Vue Way
# Stansbury Way => Stansbury Way
# Athena Way => Athena Way
# Justin Way => Justin Way
# Wistar Way => Wistar Way
# North Biltmore Way => North Biltmore Way
# Winchester Way => Winchester Way
# South Biltmore Way => South Biltmore Way
# Fort Sumter Way => Fort Sumter Way
# Trappers Way => Trappers Way
# Jacobs Way => Jacobs Way
# Dresden Way => Dresden Way
# N Highway 67 => N Highway 67
# North Highway 67 => North Highway 67
# Valley Forge => Valley Forge
# West Park Circle => West Park Circle
# Brierhall Circle => Brierhall Circle
# Trinity Circle => Trinity Circle
# Savannah Circle => Savannah Circle
# Douglas Fir Circle => Douglas Fir Circle
# Harvest Home Circle => Harvest Home Circle
# Green Pines Circle => Green Pines Circle
# Shepherds Hill Circle => Shepherds Hill Circle
# Country Squire Circle => Country Squire Circle
# Laurel Village Circle => Laurel Village Circle
# Park Ashwood Circle => Park Ashwood Circle
# Soenker Circle => Soenker Circle
# Breckenridge Circle => Breckenridge Circle
# Northwest Industrial Circle => Northwest Industrial Circle
# Maryland Circle => Maryland Circle
# Democracy Circle => Democracy Circle
# Lori Circle => Lori Circle
# NcCkay Village Circle => NcCkay Village Circle
# Georgetown Circle => Georgetown Circle
# Westhampton Place Circle => Westhampton Place Circle
# Concord View Circle => Concord View Circle
# Roselake Circle => Roselake Circle
# Jaqueline Circle => Jaqueline Circle
# McGregor Circle => McGregor Circle
# Sunset Villa Circle => Sunset Villa Circle
# Angle Gate Circle => Angle Gate Circle
# Claycrest Circle => Claycrest Circle
# Landing Circle => Landing Circle
# Mid Rivers Mall Circle => Mid Rivers Mall Circle
# Wavecrest Circle => Wavecrest Circle
# Blouff Manor Circle => Blouff Manor Circle
# Fawn Valley Circle => Fawn Valley Circle
# Ridgeland Circle => Ridgeland Circle
# Bobbinray Circle => Bobbinray Circle
# La Havre Circle => La Havre Circle
# Hennsley Circle => Hennsley Circle
# Addyston Circle => Addyston Circle
# Heather Valley Circle => Heather Valley Circle
# Jungermann Circle => Jungermann Circle
# Montague Circle => Montague Circle
# Pauley Circle => Pauley Circle
# Summergate Circle => Summergate Circle
# Delegate Circle => Delegate Circle
# Gillette Circle => Gillette Circle
# Merryfield Circle => Merryfield Circle
# England Circle => England Circle
# Plum Leaf Circle => Plum Leaf Circle
# Research Park Circle => Research Park Circle
# Bridgeton Valley Circle => Bridgeton Valley Circle
# Tri Sports Circle => Tri Sports Circle
# Imperial Circle => Imperial Circle
# Avocado Tree Circle => Avocado Tree Circle
# Hawthorne Circle => Hawthorne Circle
# Ingalls Circle => Ingalls Circle
# Asher Circle => Asher Circle
# Jacobs Creek Circle => Jacobs Creek Circle
# Pegasus Circle => Pegasus Circle
# Reddington Timbers Circle => Reddington Timbers Circle
# Bernie Circle => Bernie Circle
# Pendleton Circle => Pendleton Circle
# Haven View Circle => Haven View Circle
# Olvera Circle => Olvera Circle
# Auburn Circle => Auburn Circle
# Newkirk Circle => Newkirk Circle
# Aspencade Circle => Aspencade Circle
# Treebeard Circle => Treebeard Circle
# Waterford Crystal Circle => Waterford Crystal Circle
# Bentley Park Circle => Bentley Park Circle
# Winding Trails Circle => Winding Trails Circle
# Woodbury Place Circle => Woodbury Place Circle
# Lands End Circle => Lands End Circle
# Plantation Manor Circle => Plantation Manor Circle
# Commons Circle => Commons Circle
# Grand Slam Circle => Grand Slam Circle
# Woodmere Circle => Woodmere Circle
# Mill Pond Circle => Mill Pond Circle
# Brittany Circle => Brittany Circle
# Heritage Manor Circle => Heritage Manor Circle
# Tuckahoe Circle => Tuckahoe Circle
# Ridgetop Circle => Ridgetop Circle
# Show Boat Circle => Show Boat Circle
# Du Pre Circle => Du Pre Circle
# Country Park Circle => Country Park Circle
# Dunmore Circle => Dunmore Circle
# Berry Manor Circle => Berry Manor Circle
# Venice Circle => Venice Circle
# Magnolia Manor Circle => Magnolia Manor Circle
# Piedmont Circle => Piedmont Circle
# Logan Crossing Circle => Logan Crossing Circle
# Settlers Circle => Settlers Circle
# Belcourt Circle => Belcourt Circle
# Bardic Circle => Bardic Circle
# Twinleaf Circle => Twinleaf Circle
# Gingerwood Circle => Gingerwood Circle
# Jacobs Circle => Jacobs Circle
# Tisbury Circle => Tisbury Circle
# Saddlehorn Court East => Saddlehorn Court East
# Carriage Way East => Carriage Way East
# Jacobs Court East => Jacobs Court East
# Round Tower Drive East => Round Tower Drive East
# Mexico Loop Road East => Mexico Loop Road East
# Graybridge East => Graybridge East
# Bramblett Hills => Bramblett Hills
# Bramblett Valley => Bramblett Valley
# Bristlecone Court North => Bristlecone Court North
# Muirfield Hill Court North => Muirfield Hill Court North
# Highway 94 North => Highway 94 North
# Barley Ridge Court North => Barley Ridge Court North
# Grasslands Court North => Grasslands Court North
# Executive Centre Parkway Loop North => Executive Centre Parkway Loop North
# Valley Vista Drive North => Valley Vista Drive North
# Park Charles Boulevard North => Park Charles Boulevard North
# Ciera Ridge Court North => Ciera Ridge Court North
# Upper Muirfield Court North => Upper Muirfield Court North
# Harris Drive North => Harris Drive North
# Muirfield Court North => Muirfield Court North
# Briar Valley Court North => Briar Valley Court North
# Biddeford Court North => Biddeford Court North
# Rider Trail North => Rider Trail North
# Hutchings Farm Drive North => Hutchings Farm Drive North
# Hutchings Farm Boulevard North => Hutchings Farm Boulevard North
# Westerfield Drive North => Westerfield Drive North
# Saddlebrook Court North => Saddlebrook Court North
# N. Main Ctr. => North Main Center
# Sioux Trace => Sioux Trace
# Mohawk Trace => Mohawk Trace
# Comanche Trace => Comanche Trace
# Elmer Dwyer Club => Elmer Dwyer Club
# Hodges Club => Hodges Club
# Jacobs Ladder => Jacobs Ladder
# Via Condotti => Via Condotti
# Cades Cove => Cades Cove
# Brittany Cove => Brittany Cove
# Mystic Cove => Mystic Cove
# Cumberland Landing => Cumberland Landing
# Teal Landing => Teal Landing
# Jacobs Landing => Jacobs Landing
# Heritage Landing => Heritage Landing
# Hampton Landing => Hampton Landing
# Lexington Landing => Lexington Landing
# Gettysburg Landing => Gettysburg Landing
# Hudson Landing => Hudson Landing
# CHURCH RD => CHURCH RD
# Weule Boat Harbor => Weule Boat Harbor
# Holiday Harbor => Holiday Harbor
# Spring Mill Woods => Spring Mill Woods
# Highway 79 => Highway 79
# Old Highway 79 => Old Highway 79
# Industrial Park Place West => Industrial Park Place West
# Round Tower Drive West => Round Tower Drive West
# Saddlehorn Court West => Saddlehorn Court West
# Mexico Loop Road West => Mexico Loop Road West
# Biddeford Court West => Biddeford Court West
# Jacobs Court West => Jacobs Court West
# Douglas Drive West => Douglas Drive West
# Carriage Way West => Carriage Way West
# Garden Path => Garden Path
# Katiebriar Path => Katiebriar Path
# Arabian Path => Arabian Path
# Palomino Path => Palomino Path
# South Outer 364 => South Outer 364
# Lambert International Blvd. => Lambert International Boulevard
# Reveres Ride => Reveres Ride
# Cactus Junction => Cactus Junction
# Home Villa Loop => Home Villa Loop
# Highway C => Highway C
# Earth City Plaza => Earth City Plaza
# Magellan Plaza => Magellan Plaza
# American Eagle Plaza => American Eagle Plaza
# O'Fallon Plaza => O'Fallon Plaza
# Patterson Plaza => Patterson Plaza
# Crossroads Plaza => Crossroads Plaza
# 5th Plaza => 5th Plaza
# Runny Meade Plaza => Runny Meade Plaza
# Florissant Oaks Shopping Center => Florissant Oaks Shopping Center
# Paddock Hills Shopping Center => Paddock Hills Shopping Center
# Mid Rivers Center => Mid Rivers Center
# Mullanphy Gardens Shopping Center => Mullanphy Gardens Shopping Center
# North Main Ctr => North Main Center
# Carters Grove => Carters Grove
# Highway H => Highway H
# Highway K => Highway K
# Dorsett Village => Dorsett Village
# Woodgate Village => Woodgate Village
# Hobbs Mill => Hobbs Mill
# MO D => MO D
# West Randolph St => West Randolph Street
# Randolph St => Randolph Street
# N 4th St => N 4th Street
# N 3rd St => N 3rd Street
# Rue Saint Francois => Rue Saint Francois
# Highway P => Highway P
# Mid Rivers Mall => Mid Rivers Mall
# Highway 40-61 => Highway 40-61
# Bourbeuse Common => Bourbeuse Common
# Brimstone Corner => Brimstone Corner
# Woodmere Crossing => Woodmere Crossing
# Klondike Crossing => Klondike Crossing
# Millers Crossing => Millers Crossing
# Hampton Crossing => Hampton Crossing
# Zumwalt Crossing => Zumwalt Crossing
# Rivercity Crossing => Rivercity Crossing
# Newbury Crossing => Newbury Crossing
# Westfield Crossing => Westfield Crossing
# Heritage Crossing => Heritage Crossing
# Kings Crossing => Kings Crossing
# Chad Crossing => Chad Crossing
# Spencers Crossing => Spencers Crossing
# Rascal Crossing => Rascal Crossing
# Raintree Crossing => Raintree Crossing
# Cottage Crossing => Cottage Crossing
# Keighly Crossing => Keighly Crossing
# Kingston Crossing => Kingston Crossing
# Bramblett Crossing => Bramblett Crossing
# Chapel Hill Crossing => Chapel Hill Crossing
# Wild Fox Run => Wild Fox Run
# Timber Run => Timber Run
# Caribou Run => Caribou Run
# Grey Fox Run => Grey Fox Run
# Wallowa Run => Wallowa Run
# Elk Run => Elk Run
# Deer Run => Deer Run
# Kesslers Run => Kesslers Run
# Everwood Run => Everwood Run
# Route N => Route N
# Earth City Expressway => Earth City Expressway
# Maryland Heights Expressway => Maryland Heights Expressway
# Plaza 94 => Plaza 94
# S. Hwy  94 => South Hwy 94
# South Old Highway 94 => South Old Highway 94
# South Highway 94 => South Highway 94
# Highway 94 => Highway 94
# Bristlecone Court South => Bristlecone Court South
# Briar Valley Court South => Briar Valley Court South
# Westerfield Drive South => Westerfield Drive South
# Ciera Ridge Court South => Ciera Ridge Court South
# Hutchings Farm Drive South => Hutchings Farm Drive South
# Rider Trail South => Rider Trail South
# Saddlebrook Court South => Saddlebrook Court South
# Muirfield Court South => Muirfield Court South
# Valley Vista Drive South => Valley Vista Drive South
# Hutchings Farm Boulevard South => Hutchings Farm Boulevard South
# Upper Muirfield Court South => Upper Muirfield Court South
# Barley Ridge Court South => Barley Ridge Court South
# Park Charles Boulevard South => Park Charles Boulevard South
# Muirfield Hill Court South => Muirfield Hill Court South
# Spring Mill Creek => Spring Mill Creek
# Kingshighway => Kingshighway
# Dade => South Dade Avenue
# MO-94 => MO-94
# Wabash Manor => Wabash Manor
# Hansen Manor => Hansen Manor
# Prairie Point => Prairie Point
# Plantation Point => Plantation Point
# Pioneer Point => Pioneer Point
# Fort Saratoga => Fort Saratoga
# Morgan Trails => Morgan Trails
# Saratoga Heights => Saratoga Heights
# Musket Hollow => Musket Hollow
# Bramblett Hollow => Bramblett Hollow
# Killary Down => Killary Down
# Glen Summit => Glen Summit
# Lennox Terrace => Lennox Terrace
# Montecito Terrace => Montecito Terrace
# Knoll Terrace => Knoll Terrace
# Raintree Pass => Raintree Pass
# Rivercity Pass => Rivercity Pass
# Claremoor Pass => Claremoor Pass
# Renaud Pass => Renaud Pass
# Vantage Pass => Vantage Pass
# Zumwalt Pass => Zumwalt Pass
# Loughmor Pass => Loughmor Pass
# Donner Pass => Donner Pass
# Newgrange Pass => Newgrange Pass
# Lexington Pass => Lexington Pass
# Hughes Pass => Hughes Pass
# Chickasaw Pass => Chickasaw Pass
# Loveland Pass => Loveland Pass
# Laws Pass => Laws Pass
# Fallon Pass => Fallon Pass
# Radford Pass => Radford Pass
# St Louis Mills Blvd => Street Louis Mills Boulevard
# N Lindbergh Blvd => N Lindbergh Boulevard
# Gillette Field Close => Gillette Field Close
# Kylemore Close => Kylemore Close
# Clonmel Close => Clonmel Close
# West Meath Ring => West Meath Ring
# Preston Downs => Preston Downs
# Braxton Downs => Braxton Downs
# Merrimac Downs => Merrimac Downs
# Clydesdale Ranch => Clydesdale Ranch
# Alexandria Row => Alexandria Row
